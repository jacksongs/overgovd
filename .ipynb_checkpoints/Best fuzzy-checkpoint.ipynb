# %%
from fuzzywuzzy import process
import pandas as pd
abspop = pd.read_csv('ABS_ERP_LGA2015_08112016155122158.csv')
sapop = abspop[(abspop['LGA_2015']>39999)&(abspop['LGA_2015']<49000)]
sacounts = pd.read_csv('sacounts.csv')
# Out:
# /Users/jacksongs/anaconda3/lib/python3.5/site-packages/fuzzywuzzy-0.14.0-py3.5.egg/fuzzywuzzy/fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning

# %%
# The goal will be to receive two dataframe of equal length, name the columns subject to the match
# It produces the best joined table with a score for each


def bestfuzzy(d1,d2,c1,c2,depth=5):
    # first off, get a list of depth-length matches for each 
    matches = []
    for key in d1[c1].tolist():
        for result in process.extract(key,d2[c2].tolist(),limit=depth):
            matches.append([key,result[0],result[1]])
    test = pd.DataFrame(matches)
    common = pd.DataFrame(test.groupby(1).size().sort_values())
    return pd.merge(test,common,left_on=1,right_index=True).sort_values([2,'0_y'])
    
test = bestfuzzy(sapop,sacounts,'Region','Council',20)

# %%
test.sort_values(2,ascending=False).drop_duplicates(1)
# Out:
#                                  0_x  \
# 0                       Adelaide (C)
# 600          Maralinga Tjarutja (AC)
# 60        Anangu Pitjantjatjara (AC)
# 1040                 Roxby Downs (M)
# 800   Norwood Payneham St Peters (C)
# 901        Port Adelaide Enfield (C)
# 200                Charles Sturt (C)
# 700                Mount Gambier (C)
# 1140              Tea Tree Gully (C)
# 1220               Victor Harbor (C)
# 1300                West Torrens (C)
# 820                  Onkaparinga (C)
# 920                 Port Augusta (C)
# 420                 Holdfast Bay (C)
# 940                 Port Lincoln (C)
# 160                 Campbelltown (C)
# 1164                The Coorong (DC)
# 702                Mount Gambier (C)
# 480                       Kimba (DC)
# 964    Port Pirie City and Dists (M)
# 1240                  Wakefield (DC)
# 960    Port Pirie City and Dists (M)
# 380                      Goyder (DC)
# 560             Loxton Waikerie (DC)
# 520                     Light (RegC)
# 580                     Mallala (DC)
# 620                       Marion (C)
# 300                    Elliston (DC)
# 1181                  Tumby Bay (DC)
# 966    Port Pirie City and Dists (M)
# ...                              ...
# 840           Orroroo/Carrieton (DC)
# 440             Kangaroo Island (DC)
# 741               Murray Bridge (RC)
# 180                      Ceduna (DC)
# 280                Copper Coast (DC)
# 1160                The Coorong (DC)
# 340            Franklin Harbour (DC)
# 922                 Port Augusta (C)
# 1120                    Tatiara (DC)
# 260                 Coober Pedy (DC)
# 100                Barunga West (DC)
# 460        Karoonda East Murray (DC)
# 780              Northern Areas (DC)
# 1162                The Coorong (DC)
# 500                    Kingston (DC)
# 1381            Yorke Peninsula (DC)
# 680                Mount Barker (DC)
# 1380            Yorke Peninsula (DC)
# 1                       Adelaide (C)
# 1165                The Coorong (DC)
# 240                       Cleve (DC)
# 80                      Barossa (DC)
# 1000            Renmark Paringa (DC)
# 1080            Southern Mallee (DC)
# 1280               Wattle Range (DC)
# 40                  Alexandrina (DC)
# 642                  Mid Murray (DC)
# 220   Clare and Gilbert Valleys (DC)
# 760    Naracoorte and Lucindale (DC)
# 121           Berri and Barmera (DC)
#
#                                              1   2  0_y
# 0                                     Adelaide  95   22
# 600                         Maralinga Tjarutja  95   15
# 60                       Anangu Pitjantjatjara  95   10
# 1040                               Roxby Downs  95    8
# 800    City of Norwood, Payneham and St Peters  91   26
# 901              City of Port Adelaide Enfield  90   21
# 200                      City of Charles Sturt  88   23
# 700                      City of Mount Gambier  88   14
# 1140                    City of Tea Tree Gully  88   11
# 1220                     City of Victor Harbor  88    9
# 1300                      City of West Torrens  87   13
# 820                        City of Onkaparinga  87   11
# 920                       City of Port Augusta  87   12
